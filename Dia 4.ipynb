# %%
#Challenge 🤺 - 15 m
#Crear una clase animales que tenga atributo de clase y de instancia.

#Atributos de clase: especie.
#Atributos de instancia: nombre & color

#Luego, crear nuevos objetos a partir de las nuevas class. Imprimir el nombre y el color de los animales en una frase.
#Ejemplo: "Me llamo {nombre} y soy un ave de color {color}"..

class Animal:
    especie = "ave"

    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color

loro = Animal("Pepe", "Verde")
guacamayo = Animal("Dorotis", "rojo")

print (f"Me llamo {loro.nombre} y soy un ave de color {loro.color}")
print (f"Me llamo {guacamayo.nombre} y soy un ave de color {guacamayo.color}")
# Out:
# Me llamo Pepe y soy un ave de color Verde
# Me llamo Dorotis y soy un ave de color rojo

# %%
#Challenge 🤺
#Crear dos métodos para nuestro animal y ejecutar, debe ser algo específico de ese animal.

#Ejemplo: "Cuando hablo, digo X".
#Ejem plo: "Cuando me muevo, hago X".

class Perro:
    #Atributo de clases
    cabeza = 1
    patas = 4

    #Atributo de Instancias
    def __init__(self, nombre, color):
        self.nombre = nombre
        self.color = color
    
    #Metodo o Accion
    def camina (self, pasos):
        print (f"Cuando llamo a mi perro {mi_perro.nombre} de color {mi_perro.color}, {pasos}")

    #Metodo o Accion
    def ladra (self, sonido):
        print (f"Cuando mi perro {mi_perro.nombre} de color {mi_perro.color} me mira, el me ladra {sonido}")

#Creamos el Objeto
mi_perro = Perro ("Roqui", "blanco") #Llamo al (class Perro)

#Movemos el Objeto
mi_perro.camina("viene corriendo")
mi_perro.ladra("guau, guau")
# Out:
# Cuando llamo a mi perro Roqui de color blanco, viene corriendo
# Cuando mi perro Roqui de color blanco me mira, el me ladra guau, guau

# %%
#Challenge 🤺
#Definir una clase madre que herede a sus clases hijas dos atributos de instancia. Mostrar ambos atributos en pantalla desde los objetos de las clases hijas.

#Observación: Editar las clases hijas para que no se inicialicen.

# Clase madre
class Persona:
    def __init__(self, nombre, edad):
        self.nombre = nombre
        self.edad = edad

# Clases hijas que heredan de Persona
class Estudiante(Persona):
    pass

class Profesor(Persona):
    pass

# Crear objetos de las clases hijas
estudiante = Estudiante("Ana", 20)
profesor = Profesor("Luis", 45)

# Mostrar los atributos desde los objetos de las clases hijas
print("Estudiante:")
print("Nombre:", estudiante.nombre)
print("Edad:", estudiante.edad)

print("\nProfesor:")
print("Nombre:", profesor.nombre)
print("Edad:", profesor.edad)
# Out:
# Estudiante:
# Nombre: Ana
# Edad: 20
#
# Profesor:
# Nombre: Luis
# Edad: 45

# %%
#Challenge 1 🤺
#Escribir un programa que cree un diccionario vacío y lo vaya llenado con información sobre una persona (por ejemplo nombre, edad, sexo, teléfono, correo electrónico, etc.) que se le pida al usuario. 

#Cada vez que se añada un nuevo dato debe imprimirse el contenido del diccionario.

# Se crea un diccionario vacío para guardar los datos del usuario
datosUsuario = {}

# Definimos una función que hará las preguntas
def preguntas():
    # Paso 1: Pedir el nombre y apellido
    nombre = input('Ingrese su nombre y apellido: ')
    datosUsuario['Nombre'] = nombre  # Guardar el nombre en el diccionario
    print(datosUsuario)  # Mostrar el contenido actual

    # Paso 2: Pedir la dirección
    direccion = input('Ingrese su dirección: ')
    datosUsuario['Direccion'] = direccion
    print(datosUsuario)

    # Paso 3: Pedir el número de teléfono
    numero = input('Ingrese su número de teléfono: ')
    datosUsuario['Número'] = numero
    print(datosUsuario)

    # Paso 4: Pedir la edad y validar que sea un número
    edad = input('Ingrese su edad: ')
    if edad.isdigit():  # Validamos que sea un número
        datosUsuario['Edad'] = int(edad)
    else:
        print("❌ Edad inválida. Debe ser un número.")
    print(datosUsuario)

    # Paso 5: Mostrar resumen final
    print("\n📝 Información ingresada:")
    for clave, valor in datosUsuario.items():
        print(f"{clave}: {valor}")

# Paso 6: Llamamos a la función para que se ejecute
preguntas()
# Out:
# {'Nombre': 'vsñkfsñfñ'}
# {'Nombre': 'vsñkfsñfñ', 'Direccion': 'fnsfnk'}
# {'Nombre': 'vsñkfsñfñ', 'Direccion': 'fnsfnk', 'Número': '654654'}
# {'Nombre': 'vsñkfsñfñ', 'Direccion': 'fnsfnk', 'Número': '654654', 'Edad': 6}
#
# 📝 Información ingresada:
# Nombre: vsñkfsñfñ
# Direccion: fnsfnk
# Número: 654654
# Edad: 6

# %%
#Challenge 2 🤺
#Crear una tarjeta personal. El usuario (mediante input) puede elegir:

#Crear datos nuevos
#Modificar datos
#Eliminar datos

# Paso 1: Diccionario base para almacenar los datos del usuario
datos_usuario = {'Nombre': '', 'Apellido': '', 'Direccion': ''}

# Paso 2: Función para crear una nueva tarjeta con datos ingresados por el usuario
def crear_tarjeta():
    datos_usuario['Nombre'] = input('Ingrese su nombre: ')
    datos_usuario['Apellido'] = input('Ingrese su apellido: ')
    datos_usuario['Direccion'] = input('Ingrese su dirección: ')
    print("\n✅ Tarjeta creada:")
    print(datos_usuario)

# Paso 3: Función para modificar los datos ya existentes en la tarjeta
def modificar_tarjeta():
    datos_usuario['Nombre'] = input('Ingrese nuevo nombre: ')
    datos_usuario['Apellido'] = input('Ingrese nuevo apellido: ')
    datos_usuario['Direccion'] = input('Ingrese nueva dirección: ')
    print("\n✅ Tarjeta modificada:")
    print(datos_usuario)

# Paso 4: Función para eliminar los datos si el usuario confirma
def eliminar_tarjeta():
    confirmar = input('¿Desea eliminar todos los datos? (si/no): ')
    if confirmar.lower() == 'si':
        datos_usuario.clear()  # Elimina todos los datos del diccionario
        print("✅ Datos eliminados.")
    else:
        print("❌ Operación cancelada.")
    print(datos_usuario)

# Paso 5: Función para mostrar los datos actuales de la tarjeta
def mostrar_tarjeta():
    print("\n📄 Tarjeta actual:")
    if datos_usuario:
        for k, v in datos_usuario.items():
            print(f"{k}: {v}")
    else:
        print("No hay datos guardados.")

# Paso 6: Bucle principal para ejecutar el menú de opciones
while True:
    print("\n--- MENÚ ---")
    print("1. Crear tarjeta")
    print("2. Modificar tarjeta")
    print("3. Eliminar tarjeta")
    print("4. Mostrar tarjeta")
    print("5. Salir")

    opcion = input("Seleccione una opción (1-5): ")

    if opcion == '1':
        crear_tarjeta()
    elif opcion == '2':
        modificar_tarjeta()
    elif opcion == '3':
        eliminar_tarjeta()
    elif opcion == '4':
        mostrar_tarjeta()
    elif opcion == '5':
        print("👋 Programa finalizado.")
        break
    else:
        print("❌ Opción inválida. Intente nuevamente.")
# Out:
# {'Nombre': 'orkando', 'Apellido': 'resquin', 'Direccion': 'ñemby'}
# {'Nombre': '', 'Apellido': 'resquin', 'Direccion': 'fksñlfk'}
# Los datos fueron eliminados
# {}

# %%
#Challenge 3 🤺
#Crear una agenda de contactos. El usuario puede elegir:

#Mostrar los contactos
#Crear contacto
#Modificar datos del contacto

# Paso 1: Crear un diccionario vacío para guardar los contactos
agenda = {}

# Paso 2: Bucle principal para mostrar el menú y ejecutar opciones
while True:
    print("\n--- AGENDA DE CONTACTOS ---")
    print("1. Mostrar contactos")
    print("2. Crear contacto")
    print("3. Modificar contacto")
    print("4. Salir")

    opcion = input("Seleccione una opción (1-4): ")

    # Paso 3: Mostrar todos los contactos
    if opcion == '1':
        print("\n📒 Lista de Contactos:")
        if agenda:
            for nombre, telefono in agenda.items():
                # Mostrar los datos en formato: Nombre: [nombre] | Teléfono: [telefono]
                print(f"Nombre: {nombre} | Teléfono: {telefono}")
        else:
            print("No hay contactos guardados.")

    # Paso 4: Crear un nuevo contacto
    elif opcion == '2':
        nombre = input("Ingrese el nombre del contacto: ")
        telefono = input("Ingrese el número de teléfono: ")
        agenda[nombre] = telefono  # Agrega el nuevo contacto al diccionario
        print("✅ Contacto agregado correctamente.")

    # Paso 5: Modificar un contacto existente
    elif opcion == '3':
        nombre = input("Ingrese el nombre del contacto a modificar: ")
        if nombre in agenda:
            nuevo_telefono = input("Ingrese el nuevo número: ")
            agenda[nombre] = nuevo_telefono  # Actualiza el número
            print("✅ Contacto modificado.")
        else:
            print("❌ Contacto no encontrado.")

    # Paso 6: Salir del programa
    elif opcion == '4':
        print("👋 Cerrando la agenda.")
        break

    # Paso 7: Manejo de opciones inválidas
    else:
        print("❌ Opción no válida. Intente otra vez.")
# Out:
# --- AGENDA DE CONTACTOS ---
# 1. Mostrar contactos
# 2. Crear contacto
# 3. Modificar contacto
# 4. Salir
# ✅ Contacto agregado correctamente.
#
# --- AGENDA DE CONTACTOS ---
# 1. Mostrar contactos
# 2. Crear contacto
# 3. Modificar contacto
# 4. Salir
# ✅ Contacto agregado correctamente.
#
# --- AGENDA DE CONTACTOS ---
# 1. Mostrar contactos
# 2. Crear contacto
# 3. Modificar contacto
# 4. Salir
#
# 📒 Lista de Contactos:
# Nombre: Orlando | Teléfono: 0985690120
# Nombre: Rocio | Teléfono: 0982354256
#
# --- AGENDA DE CONTACTOS ---
# 1. Mostrar contactos
# 2. Crear contacto
# 3. Modificar contacto
# 4. Salir
# 👋 Cerrando la agenda.
